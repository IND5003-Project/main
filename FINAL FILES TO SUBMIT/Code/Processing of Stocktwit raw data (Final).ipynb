# %%
import numpy as np
import pandas as pd
import re
import html
import os.path
from datetime import datetime as dt
import math
from fractions import Fraction

from datetime import date, timedelta

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
st_raw = pd.read_csv('..data/st_raw_40000_01Oct19.csv', header=0, encoding = 'unicode_escape')

# %%
st_raw.head(2)
# Out:
#                                              message              datetime  \
# 0  $AAPL $QCOM $GOOGL $NVDA TSMC counter-sues U.S...  2019-10-01T08:41:58Z
# 1  $AAPL ð® letâs go apple ð short squeeze...  2019-10-01T08:39:08Z
#
#          user
# 0  newsfilter
# 1    Newbiest

# %%
st = st_raw.iloc[:,0:2]

# %%
st.columns=['message', 'datetime']
st.head(1)
# Out:
#                                              message              datetime
# 0  $AAPL $QCOM $GOOGL $NVDA TSMC counter-sues U.S...  2019-10-01T08:41:58Z

# %% [markdown]
# #### Create a time-series

# %%
st.datetime = st.datetime.str.replace('T', ' ')
st.datetime = st.datetime.str.replace('Z', '')

st.head(2)
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#                                              message             datetime
# 0  $AAPL $QCOM $GOOGL $NVDA TSMC counter-sues U.S...  2019-10-01 08:41:58
# 1  $AAPL ð® letâs go apple ð short squeeze...  2019-10-01 08:39:08

# %%
st['datetime'] = st['datetime'].apply(lambda x: dt.strptime(x, "%Y-%m-%d %H:%M:%S"))
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
st.sort_values(by='datetime', ascending=False)
# Out:
#                                                  message            datetime
# 0      $AAPL $QCOM $GOOGL $NVDA TSMC counter-sues U.S... 2019-10-01 08:41:58
# 1      $AAPL ð® letâs go apple ð short squeeze... 2019-10-01 08:39:08
# 2      Possible low risk trading setup on $AAPL, buy ... 2019-10-01 08:38:31
# 3      $AAPL short squeeze today. I think we will see... 2019-10-01 08:33:18
# 4      https://finance.yahoo.com/news/japan-shares-ga... 2019-10-01 08:29:54
# 5      https://finance.yahoo.com/news/chip-stocks-pro... 2019-10-01 08:29:17
# 6      It&#39;s A Fine Line Between Bullish &amp; Bea... 2019-10-01 08:27:33
# 7       $SPY $MRK $AAPL \n\nGoooooooooooood morning fam! 2019-10-01 08:25:08
# 8      $AAPL - Upcoming quarterly earning report is o... 2019-10-01 08:06:04
# 9      $AAPL &quot;Equity analysts Kyle McNealy and G... 2019-10-01 07:55:03
# 10     $AAPL Chip stocks propel gains in Europe, airl... 2019-10-01 07:46:42
# 11     Buy signal for $LB. Bullish continuation for $... 2019-10-01 07:20:00
# 12     I hear the &#39;China Trade Deal&#39; will be ... 2019-10-01 07:01:11
# 13                                     $SPY $SSNLF $AAPL 2019-10-01 06:36:41
# 14     $AAPL lower price point is making a world of d... 2019-10-01 06:11:21
# 15     $AAPL if iPhone 11 is really selling well... m... 2019-10-01 06:10:51
# 16     $AAPL The only reason for the sell off on Frid... 2019-10-01 05:47:04
# 17                 $AAPL tomorrow should be a rip âï¸ 2019-10-01 05:37:03
# 18                                         $AAPL Squeeze 2019-10-01 05:31:05
# 19     ðEvoâs Best Option Watchlist ð\n\n$AAP... 2019-10-01 05:26:48
# 20     $AAPL give me a 1.35% pullback tomorrow for th... 2019-10-01 05:03:56
# 21                                                 $AAPL 2019-10-01 04:35:52
# 22     $AAPL If the 2020 iPhone doesnât have what a... 2019-10-01 04:17:51
# 23     Watch list tomorrow:  $AAPL $AMD  $FB  $BABA  ... 2019-10-01 04:16:51
# 24     $AAPL People usually donât complain, when th... 2019-10-01 04:07:30
# 25     $SPY $amzn $aapl \n\nSo do all Bears want sena... 2019-10-01 04:06:37
# 26     $AAPL I can prove with TA that what has happen... 2019-10-01 04:04:15
# 27     $AAPL 4,000 Jan. $265 calls were bought today.... 2019-10-01 03:58:16
# 28            $AMZN $SPY $AAPL \n\nGoodnight everyone!!! 2019-10-01 03:55:08
# 29     $AMZN $SPY $AAPL $VIX \n\n...(continued presen... 2019-10-01 03:54:41
# ...                                                  ...                 ...
# 37229                                    $AAPL buy $TRNX 2019-07-29 15:35:05
# 37230         $SPY $aapl is lifting this market ðð 2019-07-29 15:34:37
# 37231  $AAPL no reason but smelling ATH after earning... 2019-07-29 15:34:34
# 37232                             $AAPL weeeeeeeeeeeð¤ 2019-07-29 15:34:33
# 37233  $AAPL Apple Reports Earnings Tuesday. Hereâs... 2019-07-29 15:34:30
# 37234  $AAPL Cramer: &#39;Better-than-feared&#39; App... 2019-07-29 15:33:53
# 37235  $AAPL $googl $amzn $NFLX   looks like apple su... 2019-07-29 15:32:33
# 37236                $AAPL whats the interest to short ? 2019-07-29 15:32:01
# 37237        $AAPL you think this is a safe play its not 2019-07-29 15:31:29
# 37238                $AAPL much more to be expected..... 2019-07-29 15:31:27
# 37239  Some #DJI earnings estimates for the current q... 2019-07-29 15:31:17
# 37240     $AAPL im sure money managers arent having fomo 2019-07-29 15:31:05
# 37241   $AAPL seems like this is being manipulated to me 2019-07-29 15:30:44
# 37242                    $AAPL .11 alerted for free ð 2019-07-29 15:30:13
# 37243  $AAPL \nTime for a straddle on this one.  Any ... 2019-07-29 15:29:47
# 37244  $AAPL This could get interesting -- Tomorrow F... 2019-07-29 15:27:42
# 37245  $AAPL well ... Iâm waiting on $BTC.X to sett... 2019-07-29 15:27:21
# 37246  $AAPL running into earnings..very nice daily t... 2019-07-29 15:27:05
# 37247                       $AAPL fake out or break out? 2019-07-29 15:26:59
# 37248                                              $AAPL 2019-07-29 15:26:19
# 37249  $AAPL We are at the beginning of a rising wave... 2019-07-29 15:25:56
# 37250  $AAPL  H&amp;H  \n \nNext resistance  is $214.... 2019-07-29 15:24:14
# 37251                  $AAPL told ya it&#39;s blowing!!! 2019-07-29 15:24:12
# 37252  $AAPL running to 211.19 (Hourly Supply) \n\nop... 2019-07-29 15:24:07
# 37253  $QQQ Price action today is just risk-off tradi... 2019-07-29 15:22:34
# 37254   $AAPL Iceberg gone. My average unit cost is $193 2019-07-29 15:22:26
# 37255                    $AAPL Massive icebergs at $210. 2019-07-29 15:21:23
# 37256             $TTD easy 270 here esp with $AAPL NEWS 2019-07-29 15:21:19
# 37257              $AAPL pump before the dump tomrw ð¤ 2019-07-29 15:20:52
# 37258                                 $SPY $AAPL ripping 2019-07-29 15:20:17
#
# [37259 rows x 2 columns]

# %%
st.set_index('datetime', inplace = True)

# %%
st.head(2)
# Out:
#                                                                message
# datetime
# 2019-10-01 08:41:58  $AAPL $QCOM $GOOGL $NVDA TSMC counter-sues U.S...
# 2019-10-01 08:39:08  $AAPL ð® letâs go apple ð short squeeze...

# %%
print('{0} number of raw data were collection from Stocktwits, dating from ({1}) to ({2}).'.format(len(st_raw), st.index[0], st.index[-1]))
# Out:
# 37259 number of raw data were collection from Stocktwits, dating from (2019-10-01 08:41:58) to (2019-07-29 15:20:17).

# %% [markdown]
# #### Cleaning the text message

# %%
st['message'] = st['message'].apply(lambda x: html.unescape(x))
st['message'] = st['message'].apply(lambda x: re.sub(r'(www\.|https?://).*?(\s|$)|@.*?(\s|$)|\$.*?(\s|$)|\d|\%|\\|/|-|_', ' ', x))
st['message'] = st['message'].apply(lambda x: re.sub(r'\s+', ' ', x))
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
st.to_csv('../data/st_pre-processed.csv', index=True)

# %% [markdown]
# #### Initialize Sentiment Analyzer

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import csv

# %%
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yan_m\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# stock market lexicon
stock_lex = pd.read_csv('../data/stock_lex.csv')

# %%
stock_lex['sentiment'] = (stock_lex['Aff_Score'] + stock_lex['Neg_Score'])/2
stock_lex = dict(zip(stock_lex.Item, stock_lex.sentiment))
stock_lex = {k:v for k,v in stock_lex.items() if len(k.split(' '))==1}

stock_lex_scaled = {}

for k, v in stock_lex.items():
    if v > 0:
        stock_lex_scaled[k] = v / max(stock_lex.values()) * 4
    else:
        stock_lex_scaled[k] = v / min(stock_lex.values()) * -4

# %%
# Loughran and McDonald
positive = []
with open('../data/lm_positive.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        positive.append(row[0].strip())
    
negative = []
with open('../data/lm_negative.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        entry = row[0].strip().split(" ")
        if len(entry) > 1:
            negative.extend(entry)
        else:
            negative.append(entry[0])

# %%
final_lex = {}
final_lex.update({word:2.0 for word in positive})
final_lex.update({word:-2.0 for word in negative})
sia.lexicon = final_lex

# %%
final_lex = {}
final_lex.update({word:2.0 for word in positive})
final_lex.update({word:-2.0 for word in negative})
final_lex.update(stock_lex_scaled)
final_lex.update(sia.lexicon)
sia.lexicon = final_lex

# %% [markdown]
# #### Conducting the SA

# %%
# demonstrating how its used
text = st.message[2]
score = sia.polarity_scores(text)['compound']

print('The text:\"{0}\" has a score of {1}.'.format(text, score))
# Out:
# The text:"Possible low risk trading setup on buy stop entry " has a score of 0.3119.

# %%
# demonstrating how sia.polarity_score is used
score = sia.polarity_scores(text)
score
# Out:
# {'neg': 0.312, 'neu': 0.0, 'pos': 0.688, 'compound': 0.3119}

# %%
st['polarity_score'] = st['message'].apply(lambda x: sia.polarity_scores(x)['compound'])
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
st.polarity_score = pd.to_numeric(st.polarity_score)
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
st[st.polarity_score == 0].sample(3)
# notice that all the text with 0 score are gibberish, emoticons or blanks after cleaning
# Out:
#                            message  polarity_score
# datetime
# 2019-07-31 18:53:19     ð¤£ fools             0.0
# 2019-09-21 01:13:47       ð¤¡ð¤¡             0.0
# 2019-07-30 17:14:26   puts crusher             0.0

# %%
st[st.polarity_score == 0].sample(3)
# Out:
#                                                    message  polarity_score
# datetime
# 2019-09-03 13:54:36                                                    0.0
# 2019-08-20 14:00:39   ðªð¼ðªð¼ðªð¼ððð             0.0
# 2019-09-10 17:07:57                      tttiiimmmbbberrrr             0.0

# %%
st.drop(st[st.polarity_score == 0].index, inplace = True)
st[st.polarity_score == 0]
# Out:
# C:\Users\yan_m\Anaconda (Active)\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# Empty DataFrame
# Columns: [message, polarity_score]
# Index: []

# %%
st.polarity_score.describe()
# Out:
# count    34875.000000
# mean         0.267105
# std          0.312965
# min         -0.917600
# 25%          0.047400
# 50%          0.240700
# 75%          0.483900
# max          0.993900
# Name: polarity_score, dtype: float64

# %%
print('After processing, the data has a length of {0}, which is {1} of the raw data extracted'.format(len(st), round(len(st)/len(st_raw), 3)))
# Out:
# After processing, the data has a length of 34875, which is 0.936 of the raw data extracted

# %% [markdown]
# #### Aggregate the sentiment scores into averages of every hour for each day

# %%
sa_daily = st.groupby(st.index.date).polarity_score.mean()
sa_daily = pd.DataFrame(sa_daily)
sa_daily.head()
# Out:
#             polarity_score
# 2019-07-29        0.308744
# 2019-07-30        0.264581
# 2019-07-31        0.264159
# 2019-08-01        0.250763
# 2019-08-02        0.245890

# %%
sa = st.groupby([st.index.date, st.index.hour]).polarity_score.mean()

# %%
sa = pd.DataFrame(sa)
sa_hrly = sa.unstack()
sa_hrly.head(2)
# Out:
#            polarity_score                                                   \
# datetime               0         1         2         3         4        5
# 2019-07-29            NaN       NaN       NaN       NaN       NaN      NaN
# 2019-07-30       0.424039  0.533864  0.273753  0.208779  0.185817  0.30738
#
#                                                  ...                      \
# datetime        6        7         8         9   ...        14        15
# 2019-07-29     NaN      NaN       NaN       NaN  ...       NaN  0.242984
# 2019-07-30  0.5767  0.40402  0.143027  0.383738  ...  0.244681  0.369641
#
#                                                                         \
# datetime          16        17        18        19        20        21
# 2019-07-29  0.266682  0.311448  0.290050  0.360893  0.247824  0.567545
# 2019-07-30  0.375432  0.225139  0.308709  0.251702  0.229684  0.261119
#
#
# datetime          22        23
# 2019-07-29  0.369104  0.363050
# 2019-07-30  0.322827  0.342034
#
# [2 rows x 24 columns]

# %%
SA = pd.concat([sa_daily, sa_hrly], axis=1, sort=False)
SA
# Out:
#             polarity_score  (polarity_score, 0)  (polarity_score, 1)  \
# 2019-07-29        0.308744                  NaN                  NaN
# 2019-07-30        0.264581             0.424039             0.533864
# 2019-07-31        0.264159             0.284620             0.412420
# 2019-08-01        0.250763             0.365681             0.334486
# 2019-08-02        0.245890             0.317523             0.294990
# 2019-08-03        0.286292             0.252029             0.199800
# 2019-08-04        0.316839             0.103450             0.086800
# 2019-08-05        0.241725             0.410647             0.124733
# 2019-08-06        0.235046             0.237384             0.312220
# 2019-08-07        0.265793             0.087521             0.268040
# 2019-08-08        0.256118             0.360050             0.333522
# 2019-08-09        0.267660             0.106300             0.471700
# 2019-08-10        0.343376             0.405150             0.126550
# 2019-08-11        0.322690             0.462967             0.176875
# 2019-08-12        0.242984             0.093278             0.258100
# 2019-08-13        0.257057             0.152933             0.003400
# 2019-08-14        0.234775             0.307576             0.298600
# 2019-08-15        0.238137             0.212116             0.298675
# 2019-08-16        0.281184             0.114300             0.290875
# 2019-08-17        0.288614             0.157563             0.245443
# 2019-08-18        0.295370             0.284900                  NaN
# 2019-08-19        0.275535             0.377638             0.395762
# 2019-08-20        0.248736             0.187582             0.282746
# 2019-08-21        0.228630             0.270200             0.095793
# 2019-08-22        0.236698             0.271540             0.197087
# 2019-08-23        0.238390             0.457650             0.206687
# 2019-08-24        0.295458             0.222060             0.378160
# 2019-08-25        0.306498             0.423127             0.458740
# 2019-08-26        0.301498             0.269626             0.267829
# 2019-08-27        0.212771             0.305464             0.297457
# 2019-09-19             0.375100  ...              0.273226
# 2019-09-20                  NaN  ...              0.234722
# 2019-09-21             0.105800  ...              0.500600
# 2019-09-22            -0.175900  ...              0.144625
# 2019-09-23             0.196850  ...              0.248330
# 2019-09-24             0.370875  ...              0.218628
# 2019-09-25             0.121800  ...              0.155644
# 2019-09-26             0.523440  ...              0.222960
# 2019-09-27             0.051000  ...              0.256505
# 2019-09-28             0.806300  ...              0.535125
# 2019-09-29                  NaN  ...              0.558120
# 2019-09-30             0.093050  ...              0.306647
# 2019-10-01             0.234914  ...                   NaN
#
#             (polarity_score, 15)  (polarity_score, 16)  (polarity_score, 17)  \
# 2019-07-29              0.242984              0.266682              0.311448
# 2019-07-30              0.369641              0.375432              0.225139
# 2019-07-31              0.237510              0.208907              0.263063
# 2019-08-01              0.213931              0.241812              0.208180
# 2019-08-02              0.268421              0.226576              0.260667
# 2019-08-03              0.225771              0.174709              0.303550
# 2019-08-04              0.285060              0.330811              0.279700
# 2019-08-05              0.306570              0.275454              0.233712
# 2019-08-06              0.203510              0.213638              0.208891
# 2019-08-07              0.284204              0.282085              0.266836
# 2019-08-08              0.168771              0.318678              0.270903
# 2019-08-09              0.139833              0.306316              0.285096
# 2019-08-10              0.554957              0.480690              0.191583
# 2019-08-11              0.342678              0.443300              0.416550
# 2019-08-12              0.307447              0.230317              0.273010
# 2019-08-13              0.304648              0.296336              0.310079
# 2019-08-14              0.160052              0.207812              0.231379
# 2019-08-15              0.213302              0.201800              0.106439
# 2019-08-16              0.299935              0.375163              0.256209
# 2019-08-17              0.122075              0.421371              0.520150
# 2019-08-18              0.350400              0.170717              0.490100
# 2019-08-19              0.332849              0.283272              0.232230
# 2019-08-20              0.257912              0.252909              0.249951
# 2019-08-21              0.209200              0.145568              0.181605
# 2019-08-22              0.153278              0.214900              0.307369
# 2019-08-23              0.216814              0.265536              0.248156
# 2019-08-24              0.265286              0.107213              0.313000
# 2019-08-25              0.301378              0.280255              0.346282
# 2019-08-26              0.235779              0.363557              0.263456
# 2019-08-27              0.191624              0.173716              0.231750
# ...                          ...                   ...                   ...
# 2019-09-02              0.458917              0.365983              0.255989
# 2019-09-03              0.351300              0.190311              0.177097
# 2019-09-04              0.235023              0.304520              0.326122
# 2019-09-05              0.298356              0.315073              0.239633
# 2019-09-06              0.295387              0.270156              0.202392
# 2019-09-07              0.197967              0.332967              0.282517
# 2019-09-08              0.643850              0.389000              0.297625
# 2019-09-09              0.335894              0.277913              0.381880
# 2019-09-10              0.305547              0.290565              0.245922
# 2019-09-11              0.281182              0.293205              0.319254
# 2019-09-12              0.277656              0.211031              0.253006
# 2019-09-13              0.240079              0.210089              0.289505
# 2019-09-14              0.286343              0.458289              0.297700
# 2019-09-15              0.331650              0.364071              0.379310
# 2019-09-16              0.284292              0.243961              0.268973
# 2019-09-17              0.350493              0.234752              0.287924
# 2019-09-18              0.313672              0.188862              0.317794
# 2019-09-19              0.222544              0.233912              0.209373
# 2019-09-20              0.229967              0.148081              0.249276
# 2019-09-21              0.332440              0.457943              0.154875
# 2019-09-22              0.359973              0.572120              0.445500
# 2019-09-23              0.310061              0.406191              0.296058
# 2019-09-24              0.177475              0.163311              0.201003
# 2019-09-25              0.245138              0.273035              0.212130
# 2019-09-26              0.293583              0.314700              0.301617
# 2019-09-27              0.152658              0.301596              0.273649
# 2019-09-28              0.389800              0.343720              0.784950
# 2019-09-29              0.481657              0.377517              0.253169
# 2019-09-30              0.238631              0.240479              0.259205
# 2019-10-01                   NaN                   NaN                   NaN
#
#             (polarity_score, 18)  (polarity_score, 19)  (polarity_score, 20)  \
# 2019-07-29              0.290050              0.360893              0.247824
# 2019-07-30              0.308709              0.251702              0.229684
# 2019-07-31              0.165255              0.260256              0.340436
# 2019-08-01              0.227058              0.228771              0.255838
# 2019-08-02              0.253843              0.258143              0.212340
# 2019-08-03              0.503230              0.316625             -0.012075
# 2019-08-04              0.253758              0.523012              0.069271
# 2019-08-05              0.225233              0.215954              0.219087
# 2019-08-06              0.206944              0.199561              0.174964
# 2019-08-07              0.249378              0.224775              0.272224
# 2019-08-08              0.282372              0.191108              0.207004
# 2019-08-09              0.184550              0.285451              0.174571
# 2019-08-10              0.320340              0.318000              0.194683
# 2019-08-11              0.392067              0.210875              0.418600
# 2019-08-12              0.260822              0.190766              0.226796
# 2019-08-13              0.253367              0.236514              0.247548
# 2019-08-14              0.269103              0.159485              0.263573
# 2019-08-15              0.197369              0.248648              0.289521
# 2019-08-16              0.149533              0.374105              0.323705
# 2019-08-17              0.591500              0.244957              0.334700
# 2019-08-18              0.516850              0.294800              0.273671
# 2019-08-19              0.270703              0.230286              0.183039
# 2019-08-20              0.150793              0.231011              0.144650
# 2019-08-21              0.208500              0.214374              0.153519
# 2019-08-22              0.270394              0.245200              0.209731
# 2019-08-23              0.207424              0.151189              0.274103
# 2019-08-24              0.178654              0.128444              0.206329
# 2019-08-25              0.258114              0.120990              0.102579
# 2019-08-26              0.249926              0.323814              0.240932
# 2019-08-27              0.262984              0.163490              0.100084
# ...                          ...                   ...                   ...
# 2019-09-02              0.160963              0.059967              0.191460
# 2019-09-03              0.232539              0.224547              0.275785
# 2019-09-04              0.341923              0.275946              0.196522
# 2019-09-05              0.217531              0.267976              0.211250
# 2019-09-06              0.326277              0.296690              0.240887
# 2019-09-07              0.403600              0.473950              0.511233
# 2019-09-08              0.594317              0.177218              0.347720
# 2019-09-09              0.226921              0.229807              0.194107
# 2019-09-10              0.266954              0.293545              0.328529
# 2019-09-11              0.277127              0.338810              0.294130
# 2019-09-12              0.288786              0.189950              0.238538
# 2019-09-13              0.309416              0.288416              0.287557
# 2019-09-14              0.520144              0.280257              0.232462
# 2019-09-15              0.213250              0.228710              0.413829
# 2019-09-16              0.300186              0.277986              0.252009
# 2019-09-17              0.226300              0.159650              0.202935
# 2019-09-18              0.201601              0.210020              0.202515
# 2019-09-19              0.284314              0.198033              0.244267
# 2019-09-20              0.349677              0.225291              0.237433
# 2019-09-21              0.325700              0.188300              0.348667
# 2019-09-22              0.249450              0.212455              0.231340
# 2019-09-23              0.273781              0.205695              0.121438
# 2019-09-24              0.252674              0.220152              0.265338
# 2019-09-25              0.254058              0.227809              0.234017
# 2019-09-26              0.303770              0.158903              0.308771
# 2019-09-27              0.256580              0.330085              0.126694
# 2019-09-28              0.138260              0.455400              0.046333
# 2019-09-29              0.479744              0.364050              0.351238
# 2019-09-30              0.305829              0.229332              0.212736
# 2019-10-01                   NaN                   NaN                   NaN
#
#             (polarity_score, 21)  (polarity_score, 22)  (polarity_score, 23)
# 2019-07-29              0.567545              0.369104              0.363050
# 2019-07-30              0.261119              0.322827              0.342034
# 2019-07-31              0.228776              0.320731              0.316997
# 2019-08-01              0.269304              0.345185              0.330112
# 2019-08-02              0.315706              0.344190              0.254372
# 2019-08-03              0.130600              0.060900              0.274800
# 2019-08-04              0.356380              0.489660              0.471408
# 2019-08-05              0.232317              0.233532              0.302269
# 2019-08-06              0.362886              0.382550              0.200722
# 2019-08-07              0.244586              0.442176              0.299415
# 2019-08-08              0.206282              0.222774              0.286427
# 2019-08-09              0.207925              0.304886              0.258950
# 2019-08-10              0.053025              0.252067              0.253533
# 2019-08-11              0.426600              0.445140              0.314762
# 2019-08-12              0.306300              0.104833              0.028600
# 2019-08-13              0.238990              0.307156              0.231069
# 2019-08-14              0.244650              0.324429              0.196163
# 2019-08-15              0.354548              0.300725              0.211244
# 2019-08-16              0.350200              0.404294              0.318433
# 2019-08-17              0.204975              0.138857              0.110075
# 2019-08-18              0.361621              0.316679              0.296858
# 2019-08-19              0.297635              0.239763              0.336862
# 2019-08-20              0.304150              0.212850              0.146658
# 2019-08-21              0.324047              0.416143              0.358414
# 2019-08-22              0.314895              0.224164              0.329657
# 2019-08-23              0.248997              0.312761              0.313167
# 2019-08-24              0.276013              0.423400              0.318713
# 2019-08-25              0.351868              0.252365              0.335042
# 2019-08-26              0.323789              0.470300              0.356993
# 2019-08-27              0.113730              0.026833              0.448664
# ...                          ...                   ...                   ...
# 2019-09-02                   NaN              0.550425              0.020320
# 2019-09-03              0.280457              0.160411              0.386382
# 2019-09-04              0.332909              0.091540              0.144522
# 2019-09-05              0.236562              0.361717              0.573567
# 2019-09-06              0.399567              0.183875              0.242457
# 2019-09-07              0.215900              0.402660              0.364300
# 2019-09-08              0.269633              0.218200              0.337177
# 2019-09-09              0.398541              0.273452              0.217700
# 2019-09-10              0.388838              0.360236              0.374777
# 2019-09-11              0.278810              0.321003              0.285355
# 2019-09-12              0.250070              0.344139              0.316300
# 2019-09-13              0.200016              0.264147              0.279228
# 2019-09-14              0.364950              0.135178              0.416100
# 2019-09-15              0.252277              0.238836              0.387337
# 2019-09-16              0.456322              0.172756              0.218967
# 2019-09-17              0.266933              0.261375              0.189357
# 2019-09-18              0.204112              0.370792              0.351094
# 2019-09-19              0.227400              0.217343              0.511721
# 2019-09-20              0.168480              0.435837              0.232819
# 2019-09-21              0.047100              0.235856              0.097957
# 2019-09-22              0.452100              0.313136              0.094758
# 2019-09-23              0.221609              0.297633              0.166845
# 2019-09-24              0.158000              0.245210              0.334554
# 2019-09-25              0.374752              0.352206              0.389557
# 2019-09-26              0.330552              0.122850              0.359715
# 2019-09-27              0.322590              0.316380              0.477463
# 2019-09-28             -0.142950              0.328943              0.477000
# 2019-09-29              0.185800              0.308667              0.342871
# 2019-09-30              0.292959              0.389587              0.358853
# 2019-10-01                   NaN                   NaN                   NaN
#
# [65 rows x 25 columns]

# %%
# SA.to_csv('../data/Sentiment_Scores_01Oct19_v2.csv', index=True)
