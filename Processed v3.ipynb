# %%
import numpy as np
import pandas as pd
import re
import html
import os.path
from datetime import datetime as dt
import math

from datetime import date, timedelta

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
st_raw = pd.read_excel('C://Users//yan_m//OneDrive//Desktop//Jupyter//IND5003//Project//data//st_raw_10000_01Oct19.xlsx', header=0, encoding = 'unicode_escape')

# %%
st_raw.head(2)
# Out:
#               Title                                         st_3SL2gug  \
# 0  DestroyTheCoiner  $AMD  Then you remember back a bit, with Obama...
# 1      GoodNewsBull  $SPY As you know @Bigmoney1977 is afraid of "r...
#
#           st_28bQfzV  st_3xRimaf lib_XwnOHoV
# 0  Sep 29th, 4:09 pm         1.0     Bullish
# 1  Sep 29th, 3:40 pm         1.0         NaN

# %%
st = st_raw.iloc[:,1:4]

# %%
st.columns=['message', 'datetime', 'likes']
st.head(1)
# Out:
#                                              message           datetime  likes
# 0  $AMD  Then you remember back a bit, with Obama...  Sep 29th, 4:09 pm    1.0

# %%
st.likes.fillna(0, inplace = True)
st.head(2)
# Out:
#                                              message           datetime  likes
# 0  $AMD  Then you remember back a bit, with Obama...  Sep 29th, 4:09 pm    1.0
# 1  $SPY As you know @Bigmoney1977 is afraid of "r...  Sep 29th, 3:40 pm    1.0

# %% [markdown]
# Create a time-series

# %%
st.datetime = st.datetime.str.replace('th,', '')
st.datetime = st.datetime.str.replace('rd,', '')
st.datetime = st.datetime.str.replace('nd,', '')
st.datetime = st.datetime.str.replace('st,', '')
# can be reduced?

st.datetime = '2019 ' + st.datetime
st.head(2)
# Out:
#                                              message             datetime  \
# 0  $AMD  Then you remember back a bit, with Obama...  2019 Sep 29 4:09 pm
# 1  $SPY As you know @Bigmoney1977 is afraid of "r...  2019 Sep 29 3:40 pm
#
#    likes
# 0    1.0
# 1    1.0

# %%
st['datetime'] = st['datetime'].apply(lambda x: dt.strptime(x, "%Y %b %d %I:%M %p"))

# %%
st.sort_values(by='datetime', ascending=False)
# Out:
#                                                 message            datetime  \
# 0     $AMD  Then you remember back a bit, with Obama... 2019-09-29 16:09:00
# 1     $SPY As you know @Bigmoney1977 is afraid of "r... 2019-09-29 15:40:00
# 2     $UVXY $TVIX $VXX $AAPL $INTC dont miss our lat... 2019-09-29 15:29:00
# 3     $SPY The Bears were hoping for that "news"to b... 2019-09-29 15:23:00
# 4     $AAPL I lived through Watergate and followed i... 2019-09-29 15:17:00
# 5     Only a matter of time before Trump is on Twitt... 2019-09-29 15:15:00
# 6     $AAPL $QQQ $SPY $ES_F $NQ_F \nIt’s time to dra... 2019-09-29 15:14:00
# 7     $FB $AMZN $AAPL $NFLX $GOOG \n\nSunday routine... 2019-09-29 14:43:00
# 8     $SPY $AAPL $AMZN $FB $TSLA \nThe Barack Obama ... 2019-09-29 14:05:00
# 9     $AAPL \nThis is what you can do on today iPad ... 2019-09-29 13:25:00
# 10        $SPY  $AAPL $AMZN  Hillary 2020, whose in?... 2019-09-29 12:50:00
# 9388                $AAPL  699 wow, actually competitve 2019-09-10 21:08:00
# 9389  $AAPL Pricing products lower than almost all t... 2019-09-10 21:08:00
# 9390                             $AAPL 699!??? WOAH!!!! 2019-09-10 21:08:00
# 9391                    $AAPL Yo.. BULLISH on the price 2019-09-10 21:08:00
# 9392          $AAPL what $699 why was the last one 1400 2019-09-10 21:08:00
# 9398                             $AAPL WOW 1 more hour! 2019-09-10 21:07:00
# 9401  $AAPL IPHONE 11\n\n•New A13 Bionic -Next Gener... 2019-09-10 21:07:00
# 9400           $AAPL is about to explode be ready!!!!🤑🤑 2019-09-10 21:07:00
# 9399                                    $AAPL ding ding 2019-09-10 21:07:00
# 9393      $AAPL fuckkk yeah 699? I can afford it hahaha 2019-09-10 21:07:00
# 9397                        $AAPL $699 I like the price 2019-09-10 21:07:00
# 9396                $AAPL $SPY  699 is a steal holy sht 2019-09-10 21:07:00
# 9395                           $AAPL I'm getting it 699 2019-09-10 21:07:00
# 9394                                              $AAPL 2019-09-10 21:07:00
# 9402                   $AAPL drops .30 with every video 2019-09-10 21:06:00
#
#       likes
# 0       1.0
# 1       1.0
# 2       1.0
# 3       5.0
# 4       1.0
# 5       3.0
# 6       4.0
# 7       2.0
# 8      17.0
# 9       3.0
# 10      2.0
# 11      2.0
# 12      2.0
# 13      1.0
# 14      0.0
# 15      1.0
# 16      0.0
# 17      0.0
# 18      0.0
# 19      1.0
# 20      0.0
# 21      1.0
# 22      2.0
# 23      0.0
# 24      6.0
# 25      0.0
# 26      3.0
# 27      6.0
# 28     10.0
# 29      0.0
# ...     ...
# 9373    1.0
# 9378    2.0
# 9380    4.0
# 9379    1.0
# 9374    1.0
# 9377    1.0
# 9376    1.0
# 9375    3.0
# 9386    4.0
# 9385    2.0
# 9384    1.0
# 9383    1.0
# 9381    2.0
# 9382    1.0
# 9387    1.0
# 9388    1.0
# 9389    1.0
# 9390    3.0
# 9391    1.0
# 9392    1.0
# 9398    1.0
# 9401    1.0
# 9400    2.0
# 9399    1.0
# 9393    2.0
# 9397    3.0
# 9396    3.0
# 9395    1.0
# 9394    1.0
# 9402    1.0
#
# [9403 rows x 3 columns]

# %%
st.set_index('datetime', inplace = True)

# %%
st.head(2)
# Out:
#                                                                message  likes
# datetime
# 2019-09-29 16:09:00  $AMD  Then you remember back a bit, with Obama...    1.0
# 2019-09-29 15:40:00  $SPY As you know @Bigmoney1977 is afraid of "r...    1.0

# %% [markdown]
# Cleaning the text message

# %%
st['message'] = st['message'].apply(lambda x: html.unescape(x))
st['message'] = st['message'].apply(lambda x: re.sub(r'(www\.|https?://).*?(\s|$)|@.*?(\s|$)|\$.*?(\s|$)|\d|\%|\\|/|-|_', ' ', x))
st['message'] = st['message'].apply(lambda x: re.sub(r'\s+', ' ', x))

# %% [markdown]
# Initialize Sentiment Analyzer

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import csv

# %%
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yan_m\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# stock market lexicon
stock_lex = pd.read_csv('C://Users//yan_m//OneDrive//Desktop//Jupyter//IND5003//Project//data//stock_lex.csv')

# %%
stock_lex['sentiment'] = (stock_lex['Aff_Score'] + stock_lex['Neg_Score'])/2
stock_lex = dict(zip(stock_lex.Item, stock_lex.sentiment))
stock_lex = {k:v for k,v in stock_lex.items() if len(k.split(' '))==1}
stock_lex_scaled = {}
for k, v in stock_lex.items():
    if v > 0:
        stock_lex_scaled[k] = v / max(stock_lex.values()) * 4
    else:
        stock_lex_scaled[k] = v / min(stock_lex.values()) * -4

# %%
# Loughran and McDonald
positive = []
with open('C://Users//yan_m//OneDrive//Desktop//Jupyter//IND5003//Project//data//lm_positive.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        positive.append(row[0].strip())
    
negative = []
with open('C://Users//yan_m//OneDrive//Desktop//Jupyter//IND5003//Project//data//lm_negative.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        entry = row[0].strip().split(" ")
        if len(entry) > 1:
            negative.extend(entry)
        else:
            negative.append(entry[0])

# %%
final_lex = {}
# final_lex.update({word:2.0 for word in positive})
# final_lex.update({word:-2.0 for word in negative})
final_lex.update(stock_lex_scaled)
final_lex.update(sia.lexicon)
sia.lexicon = final_lex

# %% [markdown]
# Conducting the SA

# %%
# demonstrating how its used
text = st.message[4]
score = sia.polarity_scores(text)['compound']

print('The text:\"{0}\" has a score of {1}.'.format(text, score))
# Out:
# The text:" I lived through Watergate and followed it closely. Apparently the Trumps are ignorant of history. When you are ignorant of history, knocking down your claims is like shooting fish in a barrel." has a score of -0.4649.

# %%
# demonstrating how sia.polarity_score is used
score = sia.polarity_scores(text)
score
# Out:
# {'neg': 0.474, 'neu': 0.269, 'pos': 0.257, 'compound': -0.4649}

# %%
st['polarity_score'] = st['message'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
st.polarity_score = pd.to_numeric(st.polarity_score)

# %%
st[st.polarity_score == 0].sample(3)
# notice that all the text with 0 score are gibberish, emoticons or blanks after cleaning
# Out:
#                        message  likes  polarity_score
# datetime
# 2019-09-12 04:02:00               2.0             0.0
# 2019-09-18 08:39:00   Powell =    2.0             0.0
# 2019-09-13 01:17:00               9.0             0.0

# %%
st.drop(st[st.polarity_score == 0].index, inplace = True)
st[st.polarity_score == 0]
# Out:
# Empty DataFrame
# Columns: [message, likes, polarity_score]
# Index: []

# %%
st.polarity_score.describe()
# Out:
# count    8381.000000
# mean        0.275738
# std         0.435324
# min        -0.973200
# 25%        -0.001600
# 50%         0.302200
# 75%         0.633700
# max         0.995000
# Name: polarity_score, dtype: float64

# %%
print('{0} number of comments in Stocktwits collected from ({1}) to ({2}) will be processed.'.format(len(st), st.index[0], st.index[-1]))
# Out:
# 8381 number of comments in Stocktwits collected from (2019-09-29 16:09:00) to (2019-09-10 21:06:00) will be processed.

# %% [markdown]
# Aggregate them into daily

# %% [markdown]
# Just average of them all

# %%
sa_daily = st.groupby(st.index.date).polarity_score.mean()
sa_daily = pd.DataFrame(sa_daily)
sa_daily.head()
# Out:
#             polarity_score
# 2019-09-10        0.311241
# 2019-09-11        0.347112
# 2019-09-12        0.283504
# 2019-09-13        0.240032
# 2019-09-14        0.311894

# %%
sa = st.groupby([st.index.date, st.index.hour]).polarity_score.mean()

# %%
sa = pd.DataFrame(sa)
sa_hrly = sa.unstack()
sa_hrly.head(2)
# Out:
#            polarity_score                                                  \
# datetime               0         1         2       3         4         5
# 2019-09-10            NaN       NaN       NaN     NaN       NaN       NaN
# 2019-09-11       0.412477  0.399679  0.357439  0.2205  0.430382  0.398306
#
#                                                   ...                      \
# datetime          6         7         8       9   ...        14        15
# 2019-09-10       NaN       NaN       NaN     NaN  ...       NaN       NaN
# 2019-09-11  0.487494  0.486581  0.533808  0.2769  ...  0.293682  0.370549
#
#                                                                        \
# datetime          16       17        18        19        20        21
# 2019-09-10       NaN      NaN       NaN       NaN       NaN  0.282418
# 2019-09-11  0.177584  0.43338  0.271156  0.353637  0.344581  0.328075
#
#
# datetime          22        23
# 2019-09-10  0.322983  0.376174
# 2019-09-11  0.334656  0.349438
#
# [2 rows x 24 columns]

# %%
SA = pd.concat([sa_daily, sa_hrly], axis=1, sort=False)
SA
# Out:
#             polarity_score  (polarity_score, 0)  (polarity_score, 1)  \
# 2019-09-10        0.311241                  NaN                  NaN
# 2019-09-11        0.347112             0.412477             0.399679
# 2019-09-12        0.283504             0.459084             0.291404
# 2019-09-13        0.240032             0.217770             0.239337
# 2019-09-14        0.311894             0.124377             0.280317
# 2019-09-15        0.260324             0.303833             0.210056
# 2019-09-16        0.285930             0.360064             0.339709
# 2019-09-17        0.229130             0.426310             0.347212
# 2019-09-18        0.264486             0.449453             0.384606
# 2019-09-19        0.253015             0.209914             0.446617
# 2019-09-20        0.237334             0.151892             0.421483
# 2019-09-21        0.314499             0.085025             0.427800
# 2019-09-22        0.305714             0.443367             0.365328
# 2019-09-23        0.258283             0.353514             0.398669
# 2019-09-24        0.266352             0.161367             0.432250
# 2019-09-25        0.278631             0.068990             0.275836
# 2019-09-26        0.277233             0.302894             0.480654
# 2019-09-27        0.289458             0.300173             0.192300
# 2019-09-28        0.306783             0.317425            -0.057300
# 2019-09-29        0.343161            -0.026400             0.348833
#
#             (polarity_score, 2)  (polarity_score, 3)  (polarity_score, 4)  \
# 2019-09-10                  NaN                  NaN                  NaN
# 2019-09-11             0.357439             0.220500             0.430382
# 2019-09-12             0.356428             0.357334             0.410096
# 2019-09-13             0.281594             0.375841             0.157436
# 2019-09-14             0.368900             0.292271             0.471714
# 2019-09-15             0.803067             0.139686             0.149686
# 2019-09-16             0.386848             0.112948             0.226200
# 2019-09-17             0.099920             0.209821             0.455117
# 2019-09-18             0.330362             0.381645            -0.054825
# 2019-09-19             0.012890             0.443611             0.292806
# 2019-09-20             0.429427             0.380720             0.293643
# 2019-09-17              0.243838              0.170219              0.094523
# 2019-09-18              0.278519              0.166989              0.204659
# 2019-09-19              0.370693              0.294958              0.317269
# 2019-09-20              0.351121              0.306533              0.284845
# 2019-09-21              0.580033              0.384875              0.571650
# 2019-09-22              0.548300              0.464237              0.341300
# 2019-09-23              0.337105              0.214616              0.226370
# 2019-09-24              0.449829              0.291030              0.254559
# 2019-09-25              0.299889              0.336200              0.283616
# 2019-09-26              0.291226              0.332786              0.204733
# 2019-09-27              0.418156              0.398905              0.261650
# 2019-09-28              0.376143              0.008137              0.031525
# 2019-09-29             -0.233133              0.869700                   NaN
#
#             (polarity_score, 18)  (polarity_score, 19)  (polarity_score, 20)  \
# 2019-09-10                   NaN                   NaN                   NaN
# 2019-09-11              0.271156              0.353637              0.344581
# 2019-09-12              0.325183              0.247032              0.187107
# 2019-09-13              0.265227              0.249534              0.291060
# 2019-09-14              0.264960              0.508322              0.424486
# 2019-09-15              0.244630              0.223243              0.516962
# 2019-09-16              0.306958              0.240350              0.358137
# 2019-09-17              0.330011              0.158524              0.158087
# 2019-09-18              0.329721              0.280339              0.265722
# 2019-09-19              0.195604              0.211800              0.084688
# 2019-09-20              0.104673              0.079843              0.193103
# 2019-09-21              0.449640              0.466483              0.285775
# 2019-09-22             -0.057933              0.738850              0.187280
# 2019-09-23              0.293076              0.357563              0.322032
# 2019-09-24              0.252382              0.177181              0.164777
# 2019-09-25              0.249202              0.260543              0.279392
# 2019-09-26              0.305820              0.273528              0.170288
# 2019-09-27              0.099972              0.194998              0.309993
# 2019-09-28              0.407113              0.404260              0.680800
# 2019-09-29                   NaN                   NaN                   NaN
#
#             (polarity_score, 21)  (polarity_score, 22)  (polarity_score, 23)
# 2019-09-10              0.282418              0.322983              0.376174
# 2019-09-11              0.328075              0.334656              0.349438
# 2019-09-12              0.437714              0.180030              0.188412
# 2019-09-13              0.243035              0.231625              0.131231
# 2019-09-14              0.486133              0.236517              0.266050
# 2019-09-15             -0.001833              0.286910              0.282900
# 2019-09-16              0.314685              0.157457              0.328112
# 2019-09-17              0.250400              0.142928              0.195256
# 2019-09-18              0.170138              0.254134              0.281231
# 2019-09-19              0.281148              0.201203              0.344539
# 2019-09-20              0.256097              0.147450              0.287305
# 2019-09-21              0.372313              0.540600              0.269800
# 2019-09-22              0.392086              0.202064              0.393960
# 2019-09-23              0.272836              0.202910              0.096696
# 2019-09-24              0.315457              0.160411              0.185967
# 2019-09-25              0.289029              0.348421              0.141858
# 2019-09-26              0.306517              0.187346              0.210426
# 2019-09-27              0.261802              0.450424              0.248331
# 2019-09-28              0.232580              0.531500             -0.086800
# 2019-09-29                   NaN                   NaN                   NaN
#
# [20 rows x 25 columns]

# %%
SA.to_csv('C://Users//yan_m//OneDrive//Desktop//Jupyter//IND5003//Project//data//Sentiment_Scores_01Oct19.csv', index=True)
